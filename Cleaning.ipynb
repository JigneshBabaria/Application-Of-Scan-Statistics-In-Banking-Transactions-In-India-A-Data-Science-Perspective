# %%
import pandas as pd

# %%
df01= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0112.xls')
df01.head(10) #Preview of the raw dataset
# Out:
#    Unnamed: 0                                         Unnamed: 1  \
# 0         NaN  NATIONAL ELECTRONIC FUND TRANSFER (NEFT) - JAN...
# 1         NaN                                               BANK
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                           ABHYUDAYA CO-OP BANK LTD
# 5         NaN                          ABU DHABI COMMERCIAL BANK
# 6         NaN                     AHMEDABAD MERCANTILE COOP BANK
# 7         NaN                                     ALLAHABAD BANK
# 8         NaN                                        ANDHRA BANK
# 9         NaN                                          AXIS BANK
#
#              Unnamed: 2     Unnamed: 3               Unnamed: 4     Unnamed: 5
# 0                   NaN            NaN                      NaN            NaN
# 1  TOTAL OUTWARD DEBITS            NaN  RECEIVED INWARD CREDITS            NaN
# ...

# %% [markdown]
# print("No. of columns containing null values")
# print(len(df.columns[df.isna().any()]))
#
# print("No. of columns not containing null values")
# print(len(df.columns[df.notna().all()]))
#
# print("Total no. of columns in the dataframe")
# print(len(df.columns))

# %%
df02= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0212.xls')
df02.head(10) #Preview of the raw dataset
# Out:
#    Unnamed: 0                                         Unnamed: 1  \
# 0         NaN  NATIONAL ELECTRONIC FUND TRANSFER (NEFT) - FEB...
# 1         NaN                                               BANK
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                           ABHYUDAYA CO-OP BANK LTD
# 5         NaN                          ABU DHABI COMMERCIAL BANK
# 6         NaN                     AHMEDABAD MERCANTILE COOP BANK
# 7         NaN                                     ALLAHABAD BANK
# 8         NaN                                        ANDHRA BANK
# 9         NaN                                          AXIS BANK
#
#              Unnamed: 2     Unnamed: 3               Unnamed: 4     Unnamed: 5
# 0                   NaN            NaN                      NaN            NaN
# 1  TOTAL OUTWARD DEBITS            NaN  RECEIVED INWARD CREDITS            NaN
# ...

# %%
df03= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0312.xls')
df03.head(10) #Preview of the raw dataset
# Out:
#    Unnamed: 0                                         Unnamed: 1  \
# 0         NaN  NATIONAL ELECTRONIC FUND TRANSFER (NEFT) - MAR...
# 1         NaN                                               BANK
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                           ABHYUDAYA CO-OP BANK LTD
# 5         NaN                          ABU DHABI COMMERCIAL BANK
# 6         NaN                     AHMEDABAD MERCANTILE COOP BANK
# 7         NaN                                     ALLAHABAD BANK
# 8         NaN                                        ANDHRA BANK
# 9         NaN                          ANZ Banking Group Limited
#
#              Unnamed: 2     Unnamed: 3               Unnamed: 4     Unnamed: 5
# 0                   NaN            NaN                      NaN            NaN
# 1  TOTAL OUTWARD DEBITS            NaN  RECEIVED INWARD CREDITS            NaN
# ...

# %%
df01= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0112.xls')
df02= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0212.xls')
df03= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0312.xls')
df04= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0412.xls')
df05= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0512.xls')
df06= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0612.xls')
df07= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0712.xls')
df08= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0812.xls')
df09= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0912.xls')
df10= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\1012.xls')
df11= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\1112.xls')
df12= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\1212.xls')

# %%
dff = pd.concat([df01,df02,df03,df04,df05,df06,df07,df08,df09,df10,df11,df12])
dff
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  NATIONAL ELECTRONIC FUND TRANSFER (NEFT) - JAN...
# 1          NaN                                               BANK
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                           ABHYUDAYA CO-OP BANK LTD
# ..         ...                                                ...
# 139        NaN                                                136
# 140        NaN                                                137
# 141        NaN                                                138
# 142        NaN                                                NaN
# 143        NaN  Total No. of Transactions in million and Amoun...
#
#                              Unnamed: 2     Unnamed: 3  \
# 0                                   NaN            NaN
# 1                  TOTAL OUTWARD DEBITS            NaN
# ...

# %%
dff.to_csv('work2.csv')

# %%
dff.columns=['0','1','2','3','4','5','6']
dg=dff.sort_values(by='1', ascending=False)
dg
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [119], in <cell line: 2>()
#       1 dff.columns=['0','1','2','3','4','5','6']
# ----> 2 dg=dff.sort_values(by='1', ascending=False)
#       3 dg
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6324, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6321     if isinstance(ascending, (tuple, list)):
#    6322         ascending = ascending[0]
# ...

# %%
dff
# Out:
#        0                                                  1  \
# 0    NaN  NATIONAL ELECTRONIC FUND TRANSFER (NEFT) - JAN...
# 1    NaN                                               BANK
# 2    NaN                                                NaN
# 3    NaN                                                NaN
# 4    NaN                           ABHYUDAYA CO-OP BANK LTD
# ..   ...                                                ...
# 139  NaN                                                136
# 140  NaN                                                137
# 141  NaN                                                138
# 142  NaN                                                NaN
# 143  NaN  Total No. of Transactions in million and Amoun...
#
#                                       2              3  \
# 0                                   NaN            NaN
# 1                  TOTAL OUTWARD DEBITS            NaN
# 2                   NO. OF TRANSACTIONS         AMOUNT
# ...

# %%
df02
# Out:
#       0                                                  1  \
# 0   NaN  NATIONAL ELECTRONIC FUND TRANSFER (NEFT) - FEB...
# 1   NaN                                               BANK
# 2   NaN                                                NaN
# 3   NaN                                                NaN
# 4   NaN                           ABHYUDAYA CO-OP BANK LTD
# ..   ..                                                ...
# 110 NaN                                           YES BANK
# 111 NaN                                              Total
# 112 NaN                         Total in Million & Billion
# 113 NaN  NOTE - Total Outwrd Debits = Total  Outward tr...
# 114 NaN  Received Inward Credits = Accounted Inward + R...
#
#                         2                3                        4  \
# 0                     NaN              NaN                      NaN
# 1    TOTAL OUTWARD DEBITS              NaN  RECEIVED INWARD CREDITS
# ...

# %%
df01.columns=['0','1','2','3','4','5']
df01.drop(['0'],axis=1,inplace=True)

df02.columns=['0','1','2','3','4','5']
df02.drop(['0'],axis=1,inplace=True)

df03.columns=['0','1','2','3','4','5']
df03.drop(['0'],axis=1,inplace=True)

df04.columns=['0','1','2','3','4','5']
df04.drop(['0'],axis=1,inplace=True)

df05.columns=['0','1','2','3','4','5']
df05.drop(['0'],axis=1,inplace=True)

df06.columns=['0','1','2','3','4','5']
df06.drop(['0'],axis=1,inplace=True)

df07.columns=['0','1','2','3','4','5','6']
df07.drop(['0','1'],axis=1,inplace=True)

df08.columns=['0','1','2','3','4','5','6']
df08.drop(['0','1'],axis=1,inplace=True)

df09.columns=['0','1','2','3','4','5','6']
df09.drop(['0','1'],axis=1,inplace=True)

df10.columns=['0','1','2','3','4','5','6']
df10.drop(['0','1'],axis=1,inplace=True)

df11.columns=['0','1','2','3','4','5','6']
df11.drop(['0','1'],axis=1,inplace=True)

df12.columns=['0','1','2','3','4','5','6']
df12.drop(['0','1'],axis=1,inplace=True)

# %%
df01
# Out:
#                                                      1                     2  \
# 0    NATIONAL ELECTRONIC FUND TRANSFER (NEFT) - JAN...                   NaN
# 1                                                 BANK  TOTAL OUTWARD DEBITS
# 2                                                  NaN   NO. OF TRANSACTIONS
# 3                                                  NaN                   NaN
# 4                             ABHYUDAYA CO-OP BANK LTD                  8963
# ..                                                 ...                   ...
# 106                                           YES BANK                474594
# 107                                              Total              20630753
# 108                         Total in Million & Billion         20.63 Million
# 109  NOTE - Total Outwrd Debits = Total  Outward tr...                   NaN
# 110  Received Inward Credits = Accounted Inward + R...                   NaN
#
# ...

# %%
df02
# Out:
#                                                      1                     2  \
# 0    NATIONAL ELECTRONIC FUND TRANSFER (NEFT) - FEB...                   NaN
# 1                                                 BANK  TOTAL OUTWARD DEBITS
# 2                                                  NaN   NO. OF TRANSACTIONS
# 3                                                  NaN                   NaN
# 4                             ABHYUDAYA CO-OP BANK LTD                  8734
# ..                                                 ...                   ...
# 110                                           YES BANK                544075
# 111                                              Total              21629978
# 112                         Total in Million & Billion         21.63 Million
# 113  NOTE - Total Outwrd Debits = Total  Outward tr...                   NaN
# 114  Received Inward Credits = Accounted Inward + R...                   NaN
#
# ...

# %%
dff = df01.merge(df02,how='right')
dff
# Out:
#                                                      1                     2  \
# 0    NATIONAL ELECTRONIC FUND TRANSFER (NEFT) - FEB...                   NaN
# 1                                                 BANK  TOTAL OUTWARD DEBITS
# 2                                                  NaN   NO. OF TRANSACTIONS
# 3                                                  NaN                   NaN
# 4                             ABHYUDAYA CO-OP BANK LTD                  8734
# ..                                                 ...                   ...
# 110                                           YES BANK                544075
# 111                                              Total              21629978
# 112                         Total in Million & Billion         21.63 Million
# 113  NOTE - Total Outwrd Debits = Total  Outward tr...                   NaN
# 114  Received Inward Credits = Accounted Inward + R...                   NaN
#
# ...

# %%
dff = df01.merge(df02,how='right',on='1').merge(df03,how='right',on='1').merge(df04,how='right',on='1').merge(df05,how='right',on='1').merge(df06,how='right',on='1').merge(df07,how='right',on='1').merge(df08,how='right',on='1').merge(df09,how='right',on='1').merge(df10,how='right',on='1').merge(df11,how='right',on='1').merge(df12,how='right',on='1')
print(dff)
# Out:
#                                                        1                  2_x  \
# 0      NATIONAL ELECTRONIC FUND TRANSFER (NEFT) - DEC...                  NaN
# 1                                                 Sr No.                  NaN
# 2                                                    NaN  NO. OF TRANSACTIONS
# 3                                                    NaN                  NaN
# 4                                                    NaN  NO. OF TRANSACTIONS
# ...                                                  ...                  ...
# 23176                                                NaN  NO. OF TRANSACTIONS
# 23177                                                NaN                  NaN
# 23178                                                NaN  NO. OF TRANSACTIONS
# 23179                                                NaN                  NaN
# 23180  Total No. of Transactions in million and Amoun...                  NaN
#
# ...

# %%
dff.to_csv('work.csv')

# %%
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 0           NaN  NATIONAL ELECTRONIC FUND TRANSFER (NEFT) - JAN...
# 1           NaN                                               BANK
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                           ABHYUDAYA CO-OP BANK LTD
# ..          ...                                                ...
# 112         NaN                                           YES BANK
# 113         NaN                                              Total
# 114         NaN                         Total in Million & Billion
# 115         NaN  NOTE - Total Outwrd Debits = Total  Outward tr...
# 116         NaN  Received Inward Credits = Accounted Inward + R...
#
#                Unnamed: 2       Unnamed: 3               Unnamed: 4  \
# 0                     NaN              NaN                      NaN
# ...

# %%
dff.columns=['0','1','2','3','4','5']
dg=dff.sort_values('1').reset_index(drop=True).head(10)
dg
# Out:
#     0                               1       2             3       4  \
# 0 NaN        ABHYUDAYA CO-OP BANK LTD   10269    645.616727   24373
# 1 NaN        ABHYUDAYA CO-OP BANK LTD    8963    508.804039   18606
# 2 NaN        ABHYUDAYA CO-OP BANK LTD    8734   1212.480408   19104
# 3 NaN       ABU DHABI COMMERCIAL BANK     817     66.753608     357
# 4 NaN       ABU DHABI COMMERCIAL BANK     889    130.484084     458
# 5 NaN       ABU DHABI COMMERCIAL BANK     931     92.389326     387
# 6 NaN  AHMEDABAD MERCANTILE COOP BANK     842     76.691135    2542
# 7 NaN  AHMEDABAD MERCANTILE COOP BANK     735      57.23558    2174
# 8 NaN  AHMEDABAD MERCANTILE COOP BANK     967     93.241853    3565
# 9 NaN                  ALLAHABAD BANK  123281  28675.525384  239056
#
#               5
# 0   1462.464579
# 1    737.046687
# 2    839.877882
# 3     72.987783
# 4     108.00342
# 5     73.090145
# 6    122.962686
# 7    122.046075
# 8    143.886864
# 9  23851.662482

# %%
for i in dg['1']:

# %%
# Out:
# 1934

# %%
# Out:
#                                            Unnamed: 0     Unnamed: 1  \
# 0   ECS - All Centres' Transaction Details For the...            NaN
# 1                                                S.No    Centre Name
# 2                                                 NaN            NaN
# 3                                                 NaN            NaN
# 4                                                   1  VISAKHAPATNAM
# ..                                                ...            ...
# 92                                                 89          ANAND
# 93                                                 90     JAMSHEDPUR
# 94                                                 91         HALDIA
# 95                                                NaN            NaN
# 96        Total (Volume in million, Value in billion)            NaN
#
#               Unnamed: 2    Unnamed: 3 Unnamed: 4           Unnamed: 5  \
# ...

# %%
df01.columns=['0','1','2','3','4','5']
df01.drop(['0'],axis=1,inplace=True)

df02.columns=['0','1','2','3','4','5']
df02.drop(['0'],axis=1,inplace=True)

df03.columns=['0','1','2','3','4','5']
df03.drop(['0'],axis=1,inplace=True)

df04.columns=['0','1','2','3','4','5']
df04.drop(['0'],axis=1,inplace=True)

df05.columns=['0','1','2','3','4','5']
df05.drop(['0'],axis=1,inplace=True)

df06.columns=['0','1','2','3','4','5']
df06.drop(['0'],axis=1,inplace=True)

df07.columns=['0','1','2','3','4','5','6']
df07.drop(['0','1'],axis=1,inplace=True)

df08.columns=['0','1','2','3','4','5','6']
df08.drop(['0','1'],axis=1,inplace=True)

df09.columns=['0','1','2','3','4','5','6']
df09.drop(['0','1'],axis=1,inplace=True)

df10.columns=['0','1','2','3','4','5','6']
df10.drop(['0','1'],axis=1,inplace=True)

df11.columns=['0','1','2','3','4','5','6']
df11.drop(['0','1'],axis=1,inplace=True)

df12.columns=['0','1','2','3','4','5','6']
df12.drop(['0','1'],axis=1,inplace=True)

# %%
df01= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\1112.xls', sheet_name='RTGS')
df01
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 0           NaN  Bank Wise RTGS Inward and Outward - November 2012
# 1           NaN                                            Sr. No.
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                  1
# ..          ...                                                ...
# 151         NaN                                                148
# 152         NaN                                                149
# 153         NaN                                                150
# 154         NaN                                                151
# 155         NaN                                                NaN
#
#                            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                 NaN        NaN        NaN        NaN
# ...

# %%
import pandas as pd

# %%
df01= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0112.xls', sheet_name='MB')
df02= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0212.xls', sheet_name='MB')
df03= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0312.xls', sheet_name='MB')
df04= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0412.xls', sheet_name='MB')
df05= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0512.xls', sheet_name='MB')
df06= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0612.xls', sheet_name='MB')
df07= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0712.xls', sheet_name='MB')
df08= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0812.xls', sheet_name='MB')
df09= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\0912.xls', sheet_name='MB')
df10= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\1012.xls', sheet_name='MB')
df11= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\1112.xls', sheet_name='MB')
df12= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\NEFT\2012\1212.xls', sheet_name='MB')

# %%
dff = pd.concat([df01,df02,df03,df04,df05,df06,df07,df08,df09,df10,df11,df12])
dff
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN   Mobile Banking Transaction of volume and valu...
# 1          NaN     Volume in Actual and Value in Thousand Rupees
# 2          NaN                                          Bank Name
# 3          NaN                                                NaN
# 4          NaN                                  BARCLAYS BANK PLC
# ..         ...                                                ...
# 48         NaN                                                 47
# 49         NaN                                                 48
# 50         NaN                                                 49
# 51         NaN                                                 50
# 52         NaN                                                NaN
#
#                                            Unnamed: 2 Unnamed: 3   Unnamed: 4  \
# 0                                                 NaN        NaN          NaN
# ...

# %%
dff.to_csv('MB.csv')

# %%
import pandas as pd

# %%
df01= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\ATM\2012\0112.xls')
df02= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\ATM\2012\0212.xls')
df03= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\ATM\2012\0312.xls')
df04= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\ATM\2012\0412.xls')
df05= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\ATM\2012\0512.xls')
df06= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\ATM\2012\0612.xls')
df07= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\ATM\2012\0712.xls')
df08= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\ATM\2012\0812.xls')
df09= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\ATM\2012\0912.xls')
df10= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\ATM\2012\1012.xls')
df11= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\ATM\2012\1112.xls')
df12= pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\ATM\2012\1212.xls')

# %%
dff = pd.concat([df01,df02,df03,df04,df05,df06,df07,df08,df09,df10,df11,df12])
dff
# Out:
#    Bank wise ATM  and Card Statistics -January 2012      Unnamed: 1  \
# 0                                           Sr. No.       Bank Name
# 1                                               NaN             NaN
# 2                                               NaN             NaN
# 3                                                 1  Allahabad Bank
# 4                                                 2     Andhra Bank
# ..                                              ...             ...
# 54                                              NaN    Vijaya  Bank
# 55                                              NaN   Yes Bank Ltd.
# 56                                              NaN     Grand Total
# 57                                              NaN             NaN
# 58                                              NaN             NaN
#
#         Unnamed: 2 Unnamed: 3               Unnamed: 4 Unnamed: 5  \
# 0   Number of ATMs        NaN  Number of POS terminals        NaN
# ...

# %%
dff.to_csv('2012_ATM.csv')

# %%
dfa = pd.read_excel(r'D:\Study\Project\Bank Transaction Analysis\ATM\2022\1222.xlsx')
dfa
# Out:
#     Unnamed: 0  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 97          22
# 98          23
# 99          24
# 100         25
# 101         26
#
#     ATM, Acceptance Infrastructure and Card Statistics for the Month of DECEMBER 2022  \
# 0                                              Sr. No.
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 97   Total value of other financial transactions do...
# 98   Total number of cash withdrawal transactions d...
# 99   Total value of cash withdrawal transactions do...
# 100  Total number of cash withdrawal transactions d...
# 101  Total value of cash withdrawal transactions do...
#
# ...

# %%
df01= pd.read_csv(r'C:\Users\jigne\2012_RTGS.csv')
df02= pd.read_csv(r'C:\Users\jigne\2013_RTGS.csv')
df03= pd.read_csv(r'C:\Users\jigne\2014_RTGS.csv')
df04= pd.read_csv(r'C:\Users\jigne\2015_RTGS.csv')
df05= pd.read_csv(r'C:\Users\jigne\2016_RTGS.csv')
df06= pd.read_csv(r'C:\Users\jigne\2017_RTGS.csv')
df07= pd.read_csv(r'C:\Users\jigne\2018_RTGS.csv')
df08= pd.read_csv(r'C:\Users\jigne\2019_RTGS.csv')
df09= pd.read_csv(r'C:\Users\jigne\2020_RTGS.csv')
df10= pd.read_csv(r'C:\Users\jigne\2021_RTGS.csv')
df11= pd.read_csv(r'C:\Users\jigne\2022_RTGS.csv')

# %%
dff = pd.concat([df01,df02,df03,df04,df05,df06,df07,df08,df09,df10,df11])
dff
# Out:
#                                            BANK C VOLUME     C VALUE  \
# 0     A. P. MAHESH CO-OP URBAN BANK LTD. - 2012    15334   27.457255
# 1               ABHYUDAYA CO-OP BANK LTD - 2012    37284  129.862384
# 2                     ABN AMRO BANK N.V. - 2012    56535  580.600150
# 3              ABU DHABI COMMERCIAL BANK - 2012     2805  180.134502
# 4         AHMEDABAD MERCANTILE COOP BANK - 2012     3797    4.135977
# ...                                         ...      ...         ...
# 2915                                        NaN      NaN         NaN
# 2916                                        NaN      NaN         NaN
# 2917                                        NaN      NaN         NaN
# 2918                                        NaN      NaN         NaN
# 2919                                        244    TOTAL  100.000000
#
#       D VOLUME     D VALUE  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# ...

# %%
dff.to_csv('RTGS2.csv')

# %%
df01= pd.read_csv(r'C:\Users\jigne\2012_NEFT.csv')
df02= pd.read_csv(r'C:\Users\jigne\2013_NEFT.csv')
df03= pd.read_csv(r'C:\Users\jigne\2014_NEFT.csv')
df04= pd.read_csv(r'C:\Users\jigne\2015_NEFT.csv')
df05= pd.read_csv(r'C:\Users\jigne\2016_NEFT.csv')
df06= pd.read_csv(r'C:\Users\jigne\2017_NEFT.csv')
df07= pd.read_csv(r'C:\Users\jigne\2018_NEFT.csv')
df08= pd.read_csv(r'C:\Users\jigne\2019_NEFT.csv')
df09= pd.read_csv(r'C:\Users\jigne\2020_NEFT.csv')
df10= pd.read_csv(r'C:\Users\jigne\2021_NEFT.csv')
df11= pd.read_csv(r'C:\Users\jigne\2022_NEFT.csv')

# %%
dff = pd.concat([df01,df02,df03,df04,df05,df06,df07,df08,df09,df10,df11])
dff
# Out:
#                                                   BANK    DC VOLUME  \
# 0     A. P. MAHESH CO-OPERATIVE URBAN BANK LTD. - 2012      17686.0
# 1               ABHYUDAYA CO-OPERATIVE BANK LTD - 2012     128282.0
# 2                     ABU DHABI COMMERCIAL BANK - 2012      10548.0
# 3    AHMEDABAD MERCANTILE CO-OPERATIVE BANK LTD. - ...      12634.0
# 4                                ALLAHABAD BANK - 2012    2450155.0
# ..                                                 ...          ...
# 228               VASAI VIKAS SAHAKARI BANK LTD - 2022      66610.0
# 229          WEST BENGAL STATE COOPERATIVE BANK - 2022     714374.0
# 230                                  WOORI BANK - 2022     141047.0
# 231                                    YES BANK - 2022  843100970.0
# 232             ZILA SAHKARI BANK LTD GHAZIABAD - 2022      44877.0
#
#          DC VALUE   CC VOLUME      CC VALUE BANK   DC VOLUME   DC VALUEE  \
# 0    6.553137e+02     10672.0  4.697708e+02   NaN         NaN        NaN
# ...

# %%
dff.to_csv('NEFT2.csv')

# %%
c = pd.read_excel(r'C:\Users\jigne\OneDrive\Desktop\New folder\2012.xlsx', sheet_name = 'CC')
c
# Out:
#                              Banks             1             2             3  \
# 0                   Allahabad Bank      0.000000      0.000000      0.000000
# 1      American Express Bkg. Corp.  12520.068152  12897.898677  13492.881985
# 2                      Andhra Bank    313.600000    268.500000    277.100000
# 3                   Axis Bank Ltd.   2350.500000   2291.317542   2772.250564
# 4                   Bank of Baroda    201.365774    197.433411    209.500000
# 5                    Bank of India    304.500000    277.400000    300.300000
# 6              Bank of Maharashtra     35.200000     32.900000     34.300000
# 7                   Barclays Bank     293.059384      0.172375      0.000000
# 8                      Canara Bank    191.500000    165.600000    178.100000
# 9        Catholic Syrian Bank Ltd.      0.000000      0.000000      0.000000
# 10           Central Bank of India     19.800000     18.700000     21.300000
# ...

# %%
cc = c[['Bank','Total(Billion)']]
cc.to_excel('2012_CC.xlsx')

# %%
c = pd.read_excel(r'C:\Users\jigne\OneDrive\Desktop\New folder\2012.xlsx', sheet_name = 'DC')
cc = c[['Banks','Total(Billion)']]
cc.to_excel('2012_DC.xlsx')

# %%
c = pd.read_excel(r'C:\Users\jigne\OneDrive\Desktop\New folder\2013.xlsx', sheet_name = 'DC')
cc = c[['Bank','Total(Billion)']]
cc.to_excel('2013_DC.xlsx')

# %%
c = pd.read_excel(r'C:\Users\jigne\OneDrive\Desktop\New folder\2014.xlsx', sheet_name = 'DC')
cc = c[['Bank','Total(Billion)']]
cc.to_excel('2014_DC.xlsx')

# %%
c = pd.read_excel(r'C:\Users\jigne\OneDrive\Desktop\New folder\2015.xlsx', sheet_name = 'DC')
cc = c[['Bank','Total(Billion)']]
cc.to_excel('2015_DC.xlsx')

# %%
c = pd.read_excel(r'C:\Users\jigne\OneDrive\Desktop\New folder\2016.xlsx', sheet_name = 'DC')
cc = c[['Bank','Total(Billion)']]
cc.to_excel('2016_DC.xlsx')

# %%
c = pd.read_excel(r'C:\Users\jigne\OneDrive\Desktop\New folder\2017.xlsx', sheet_name = 'DC')
cc = c[['Bank','Total(Billion)']]
cc.to_excel('2017_DC.xlsx')

# %%
c = pd.read_excel(r'C:\Users\jigne\OneDrive\Desktop\New folder\2018.xlsx', sheet_name = 'DC')
cc = c[['Bank','Total(Billion)']]
cc.to_excel('2018_DC.xlsx')

# %%
c = pd.read_excel(r'C:\Users\jigne\OneDrive\Desktop\New folder\2019.xlsx', sheet_name = 'DC')
cc = c[['Bank','Total(Billion)']]
cc.to_excel('2019_DC.xlsx')

# %%
c = pd.read_excel(r'C:\Users\jigne\OneDrive\Desktop\New folder\2020.xlsx', sheet_name = 'DC')
cc = c[['Bank','Total(Billion)']]
cc.to_excel('2020_DC.xlsx')

# %%
c = pd.read_excel(r'C:\Users\jigne\OneDrive\Desktop\New folder\2021.xlsx', sheet_name = 'DC')
cc = c[['Bank','Total(Billion)']]
cc.to_excel('2021_DC.xlsx')

# %%
c = pd.read_excel(r'C:\Users\jigne\OneDrive\Desktop\New folder\2022.xlsx', sheet_name = 'DC')
cc = c[['Banks','Total(Billions)']]
cc.to_excel('2022_DC.xlsx')

# %%
df01= pd.read_csv(r'C:\Users\jigne\2012_MB.csv')
df02= pd.read_csv(r'C:\Users\jigne\2013_MB.csv')
df03= pd.read_csv(r'C:\Users\jigne\2014_MB.csv')
df04= pd.read_csv(r'C:\Users\jigne\2015_MB.csv')
df05= pd.read_csv(r'C:\Users\jigne\2016_MB.csv')
df06= pd.read_csv(r'C:\Users\jigne\2017_MB.csv')
df07= pd.read_csv(r'C:\Users\jigne\2018_MB.csv')
df08= pd.read_csv(r'C:\Users\jigne\2019_MB.csv')
df09= pd.read_csv(r'C:\Users\jigne\2020_MB.csv')
df10= pd.read_csv(r'C:\Users\jigne\2021_MB.csv')
df11= pd.read_csv(r'C:\Users\jigne\2022_MB.csv',  encoding='windows-1252')

# %%
dff = pd.concat([df01,df02,df03,df04,df05,df06,df07,df08,df09,df10,df11])
dff
# Out:
#                                                   BANK       VOLUME  \
# 0             A. P. MAHESH CO-OP URBAN BANK LTD - 2012      36814.0
# 1                                ALLAHABAD BANK - 2012      10958.0
# 2                                   ANDHRA BANK - 2012     120355.0
# 3                                 AXIS BANK LTD - 2012    2761955.0
# 4                                BANK OF BARODA - 2012     278919.0
# ..                                                 ...          ...
# 506  WARANGAL DISTRICT CENTRAL CO OPERATIVE BANK LT...        834.0
# 507                WARANGAL URBAN COOP BANK LTD - 2022      25444.0
# 508             WARDHAMAN URBAN CO-OP BANK LTD. - 2022      17813.0
# 509                                  WOORI BANK - 2022       7801.0
# 510                            YES BANK LIMITED - 2022  387792177.0
#
#            VALUE  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# ...

# %%
dff.to_excel('MB.xlsx')

# %%
import pandas as pd
from openpyxl import load_workbook

# %%
c = pd.read_excel(r'C:\Users\jigne\2012_CC.xlsx')
d = pd.read_excel(r'C:\Users\jigne\2012_DC.xlsx')
cd = c.merge(d, on='Bank', how='outer')
cd.fillna(0, inplace=True)
o = cd[['Bank','Total(Billion)_x','Total(Billion)_y']]
o.columns = ["BANK","CC","DC"]
book = load_workbook('CARD.xlsx')
writer = pd.ExcelWriter('CARD.xlsx', engine='openpyxl') 
writer.book = book
o.to_excel(writer, sheet_name = '2012')
writer.close()

# %%
c = pd.read_excel(r'C:\Users\jigne\2013_CC.xlsx')
d = pd.read_excel(r'C:\Users\jigne\2013_DC.xlsx')
cd = c.merge(d, on='Bank', how='outer')
cd.fillna(0, inplace=True)
o = cd[['Bank','Total(Billion)_x','Total(Billion)_y']]
o.columns = ["BANK","CC","DC"]
book = load_workbook('CARD.xlsx')
writer = pd.ExcelWriter('CARD.xlsx', engine='openpyxl') 
writer.book = book
o.to_excel(writer, sheet_name = '2013')
writer.close()

# %%
c = pd.read_excel(r'C:\Users\jigne\2014_CC.xlsx')
d = pd.read_excel(r'C:\Users\jigne\2014_DC.xlsx')
cd = c.merge(d, on='Bank', how='outer')
cd.fillna(0, inplace=True)
o = cd[['Bank','Total(Billion)_x','Total(Billion)_y']]
o.columns = ["BANK","CC","DC"]
book = load_workbook('CARD.xlsx')
writer = pd.ExcelWriter('CARD.xlsx', engine='openpyxl') 
writer.book = book
o.to_excel(writer, sheet_name = '2014')
writer.close()

# %%
c = pd.read_excel(r'C:\Users\jigne\2015_CC.xlsx')
d = pd.read_excel(r'C:\Users\jigne\2015_DC.xlsx')
cd = c.merge(d, on='Bank', how='outer')
cd.fillna(0, inplace=True)
o = cd[['Bank','Total(Billion)_x','Total(Billion)_y']]
o.columns = ["BANK","CC","DC"]
book = load_workbook('CARD.xlsx')
writer = pd.ExcelWriter('CARD.xlsx', engine='openpyxl') 
writer.book = book
o.to_excel(writer, sheet_name = '2015')
writer.close()

# %%
c = pd.read_excel(r'C:\Users\jigne\2016_CC.xlsx')
d = pd.read_excel(r'C:\Users\jigne\2016_DC.xlsx')
cd = c.merge(d, on='Bank', how='outer')
cd.fillna(0, inplace=True)
o = cd[['Bank','Total(Billion)_x','Total(Billion)_y']]
o.columns = ["BANK","CC","DC"]
book = load_workbook('CARD.xlsx')
writer = pd.ExcelWriter('CARD.xlsx', engine='openpyxl') 
writer.book = book
o.to_excel(writer, sheet_name = '2016')
writer.close()

# %%
c = pd.read_excel(r'C:\Users\jigne\2017_CC.xlsx')
d = pd.read_excel(r'C:\Users\jigne\2017_DC.xlsx')
cd = c.merge(d, on='Bank', how='outer')
cd.fillna(0, inplace=True)
o = cd[['Bank','Total(Billion)_x','Total(Billion)_y']]
o.columns = ["BANK","CC","DC"]
book = load_workbook('CARD.xlsx')
writer = pd.ExcelWriter('CARD.xlsx', engine='openpyxl') 
writer.book = book
o.to_excel(writer, sheet_name = '2017')
writer.close()

# %%
c = pd.read_excel(r'C:\Users\jigne\2018_CC.xlsx')
d = pd.read_excel(r'C:\Users\jigne\2018_DC.xlsx')
cd = c.merge(d, on='Bank', how='outer')
cd.fillna(0, inplace=True)
o = cd[['Bank','Total(Billion)_x','Total(Billion)_y']]
o.columns = ["BANK","CC","DC"]
book = load_workbook('CARD.xlsx')
writer = pd.ExcelWriter('CARD.xlsx', engine='openpyxl') 
writer.book = book
o.to_excel(writer, sheet_name = '2018')
writer.close()

# %%
c = pd.read_excel(r'C:\Users\jigne\2019_CC.xlsx')
d = pd.read_excel(r'C:\Users\jigne\2019_DC.xlsx')
cd = c.merge(d, on='Bank', how='outer')
cd.fillna(0, inplace=True)
o = cd[['Bank','Total(Billion)_x','Total(Billion)_y']]
o.columns = ["BANK","CC","DC"]
book = load_workbook('CARD.xlsx')
writer = pd.ExcelWriter('CARD.xlsx', engine='openpyxl') 
writer.book = book
o.to_excel(writer, sheet_name = '2019')
writer.close()

# %%
c = pd.read_excel(r'C:\Users\jigne\2020_CC.xlsx')
d = pd.read_excel(r'C:\Users\jigne\2020_DC.xlsx')
cd = c.merge(d, on='Bank', how='outer')
cd.fillna(0, inplace=True)
o = cd[['Bank','Total(Billion)_x','Total(Billion)_y']]
o.columns = ["BANK","CC","DC"]
book = load_workbook('CARD.xlsx')
writer = pd.ExcelWriter('CARD.xlsx', engine='openpyxl') 
writer.book = book
o.to_excel(writer, sheet_name = '2020')
writer.close()

# %%
c = pd.read_excel(r'C:\Users\jigne\2021_CC.xlsx')
d = pd.read_excel(r'C:\Users\jigne\2021_DC.xlsx')
cd = c.merge(d, on='Bank', how='outer')
cd.fillna(0, inplace=True)
o = cd[['Bank','Total(Billion)_x','Total(Billion)_y']]
o.columns = ["BANK","CC","DC"]
book = load_workbook('CARD.xlsx')
writer = pd.ExcelWriter('CARD.xlsx', engine='openpyxl') 
writer.book = book
o.to_excel(writer, sheet_name = '2021')
writer.close()

# %%
c = pd.read_excel(r'C:\Users\jigne\2022_CC.xlsx')
d = pd.read_excel(r'C:\Users\jigne\2022_DC.xlsx')
cd = c.merge(d, on='Bank', how='outer')
cd.fillna(0, inplace=True)
o = cd[['Bank','Total(Billion)_x','Total(Billion)_y']]
o.columns = ["BANK","CC","DC"]
book = load_workbook('CARD.xlsx')
writer = pd.ExcelWriter('CARD.xlsx', engine='openpyxl') 
writer.book = book
o.to_excel(writer, sheet_name = '2022')
writer.close()

# %%
m = pd.read_csv(r'C:\Users\jigne\2012_MB.csv')
m.fillna(0, inplace=True)
book = load_workbook('MOBILE.xlsx')
writer = pd.ExcelWriter('MOBILE.xlsx', engine='openpyxl') 
writer.book = book
m.to_excel(writer, sheet_name = '2012')
writer.close()

# %%
m = pd.read_csv(r'C:\Users\jigne\2013_MB.csv')
m.fillna(0, inplace=True)
book = load_workbook('MOBILE.xlsx')
writer = pd.ExcelWriter('MOBILE.xlsx', engine='openpyxl') 
writer.book = book
m.to_excel(writer, sheet_name = '2013')
writer.close()

# %%
m = pd.read_csv(r'C:\Users\jigne\2014_MB.csv')
m.fillna(0, inplace=True)
book = load_workbook('MOBILE.xlsx')
writer = pd.ExcelWriter('MOBILE.xlsx', engine='openpyxl') 
writer.book = book
m.to_excel(writer, sheet_name = '2014')
writer.close()

# %%
m = pd.read_csv(r'C:\Users\jigne\2015_MB.csv')
m.fillna(0, inplace=True)
book = load_workbook('MOBILE.xlsx')
writer = pd.ExcelWriter('MOBILE.xlsx', engine='openpyxl') 
writer.book = book
m.to_excel(writer, sheet_name = '2015')
writer.close()

# %%
m = pd.read_csv(r'C:\Users\jigne\2016_MB.csv')
m.fillna(0, inplace=True)
book = load_workbook('MOBILE.xlsx')
writer = pd.ExcelWriter('MOBILE.xlsx', engine='openpyxl') 
writer.book = book
m.to_excel(writer, sheet_name = '2016')
writer.close()

# %%
m = pd.read_csv(r'C:\Users\jigne\2017_MB.csv')
m.fillna(0, inplace=True)
book = load_workbook('MOBILE.xlsx')
writer = pd.ExcelWriter('MOBILE.xlsx', engine='openpyxl') 
writer.book = book
m.to_excel(writer, sheet_name = '2017')
writer.close()

# %%
m = pd.read_csv(r'C:\Users\jigne\2018_MB.csv')
m.fillna(0, inplace=True)
book = load_workbook('MOBILE.xlsx')
writer = pd.ExcelWriter('MOBILE.xlsx', engine='openpyxl') 
writer.book = book
m.to_excel(writer, sheet_name = '2018')
writer.close()

# %%
m = pd.read_csv(r'C:\Users\jigne\2019_MB.csv', encoding='windows-1252')
m.fillna(0, inplace=True)
book = load_workbook('MOBILE.xlsx')
writer = pd.ExcelWriter('MOBILE.xlsx', engine='openpyxl') 
writer.book = book
m.to_excel(writer, sheet_name = '2019')
writer.close()

# %%
m = pd.read_csv(r'C:\Users\jigne\2020_MB.csv')
m.fillna(0, inplace=True)
book = load_workbook('MOBILE.xlsx')
writer = pd.ExcelWriter('MOBILE.xlsx', engine='openpyxl') 
writer.book = book
m.to_excel(writer, sheet_name = '2020')
writer.close()

# %%
m = pd.read_csv(r'C:\Users\jigne\2021_MB.csv', encoding='windows-1252')
m.fillna(0, inplace=True)
book = load_workbook('MOBILE.xlsx')
writer = pd.ExcelWriter('MOBILE.xlsx', engine='openpyxl') 
writer.book = book
m.to_excel(writer, sheet_name = '2021')
writer.close()

# %%
m = pd.read_csv(r'C:\Users\jigne\2022_MB.csv', encoding='windows-1252')
m.fillna(0, inplace=True)
book = load_workbook('MOBILE.xlsx')
writer = pd.ExcelWriter('MOBILE.xlsx', engine='openpyxl') 
writer.book = book
m.to_excel(writer, sheet_name = '2022')
writer.close()

# %%
df01= pd.read_excel(r'C:\Users\jigne\2012_DC.xlsx')
df02= pd.read_excel(r'C:\Users\jigne\2013_DC.xlsx')
df03= pd.read_excel(r'C:\Users\jigne\2014_DC.xlsx')
df04= pd.read_excel(r'C:\Users\jigne\2015_DC.xlsx')
df05= pd.read_excel(r'C:\Users\jigne\2016_DC.xlsx')
df06= pd.read_excel(r'C:\Users\jigne\2017_DC.xlsx')
df07= pd.read_excel(r'C:\Users\jigne\2018_DC.xlsx')
df08= pd.read_excel(r'C:\Users\jigne\2019_DC.xlsx')
df09= pd.read_excel(r'C:\Users\jigne\2020_DC.xlsx')
df10= pd.read_excel(r'C:\Users\jigne\2021_DC.xlsx')
df11= pd.read_excel(r'C:\Users\jigne\2022_DC.xlsx')

# %%
dff = df01.merge(df02,how='outer',on='Bank').merge(df03,how='outer',on='Bank').merge(df04,how='outer',on='Bank').merge(df05,how='outer',on='Bank').merge(df06,how='outer',on='Bank').merge(df07,how='outer',on='Bank').merge(df08,how='outer',on='Bank').merge(df09,how='outer',on='Bank').merge(df10,how='outer',on='Bank').merge(df11,how='outer',on='Bank')
print(dff)
# Out:
#                                    Bank         2012         2013  \
# 0                        ALLAHABAD BANK    62.122358   100.873344
# 1                      AMERICAN EXPRESS     0.000000     0.000000
# 2                           ANDHRA BANK   239.992900   271.981300
# 3                         AXIS BANK LTD  1337.286274  1432.725578
# 4                        BANK OF BARODA   386.136339   494.950788
# ..                                  ...          ...          ...
# 92                       SBM BANK INDIA          NaN          NaN
# 93                    NAINITAL BANK LTD          NaN          NaN
# 94  SHIVALIK SMALL FINANCE BANK LIMITED          NaN          NaN
# 95     UNITY SMALL FINANCE BANK LIMITED          NaN          NaN
# 96                           WOORI BANK          NaN          NaN
#
#            2014         2015         2016         2017         2018  \
# 0    132.157761   162.409932   187.157372   235.865286   286.227542
# ...

# %%
dff.to_excel('DC.xlsx')
